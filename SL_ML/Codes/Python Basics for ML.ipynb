# %%
print("Hello world")
# Out:
# Hello world

# %%
print('Hello World')
# Out:
# Hello World

# %%
print('It\'s a hot day here')
# Out:
# It's a hot day here

# %%
print("It's a hot day here")
# Out:
# It's a hot day here

# %%
print('''My name is manna''')
# Out:
# My name is manna

# %%
print("Python for Beginners")
# Out:
# Python for Beginners

# %%
course = "Python for Beginners"

# %%
print(course)
# Out:
# Python for Beginners

# %%
type(course)
# Out:
# str

# %%
num = 24

# %%
type(num)
# Out:
# int

# %%
num = '24'

# %%
type(num)
# Out:
# str

# %%
type(24)
# Out:
# int

# %%
type(24.0)
# Out:
# float

# %%
num = 24

# %%
num2 = 23

# %%
num3 = num + num2

# %%
num3
# Out:
# 47

# %%
str1 = "Hello"
str2 = "World"

# %%
str3 = str1 + " " + str2

# %%
str3
# Out:
# 'Hello World'

# %%
var1 = str1 + str(num)

# %%
var1
# Out:
# 'Hello24'

# %%
4 > 7
# Out:
# False

# %%
4 < 7
# Out:
# True

# %%
type(True) #This is a comment
# Out:
# bool

# %%
print(course)
# Out:
# Python for Beginners

# %%
course
# Out:
# 'Python for Beginners'

# %% [markdown]
# String Operations

# %%
course[0]
# Out:
# 'P'

# %%
course[7]
# Out:
# 'f'

# %%
course[6]
# Out:
# ' '

# %%
course[0:6]
# Out:
# 'Python'

# %%
course[:6]
# Out:
# 'Python'

# %%
course
# Out:
# 'Python for Beginners'

# %%
course[7:10]
# Out:
# 'for'

# %%
course[7:]
# Out:
# 'for Beginners'

# %%
course[:]
# Out:
# 'Python for Beginners'

# %%
course[-2]
# Out:
# 'r'

# %%
course[:-1]
# Out:
# 'Python for Beginner'

# %% [markdown]
# For Reversing string

# %%
course[::-1]
# Out:
# 'srennigeB rof nohtyP'

# %%
course[::-2]
# Out:
# 'sengBrfnhy'

# %%
course[::2]
# Out:
# 'Pto o einr'

# %%
course
# Out:
# 'Python for Beginners'

# %%
"Python" in course
# Out:
# True

# %%
"python" in course
# Out:
# False

# %%
"P" in course
# Out:
# True

# %%
len(course)
# Out:
# 20

# %% [markdown]
# String opearations

# %%
course.lower()
# Out:
# 'python for beginners'

# %%
course.upper()
# Out:
# 'PYTHON FOR BEGINNERS'

# %%
course.title()
# Out:
# 'Python For Beginners'

# %% [markdown]
# User Input

# %%
name = input("Please enter your name \n")
# Out:
# Please enter your name
# Liqzan

# %%
num4 = input("Please enter your Weight: \n")
# Out:
# Please enter your Weight:
# 80

# %%
num4
# Out:
# '80'

# %%
type(num4)
# Out:
# str

# %%
num4 = int(input("Please enter your Weight: \n"))
# Out:
# Please enter your Weight:
# 80

# %%
num4
# Out:
# 80

# %%
type(num4)
# Out:
# int

# %%
num4 = int(input("Please enter your Weight: \n"))
# Out:
# Please enter your Weight:
# 80.2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-68924af20069> in <module>()
# ----> 1 num4 = int(input("Please enter your Weight: \n"))
#
# ValueError: invalid literal for int() with base 10: '80.2'

# %% [markdown]
# Assigment :
# 1. Take the user name
# 2. Ask the weight of the user
# 3. Print the name and weight of user in a single line

# %% [markdown]
# To count number of words in a string

# %%
course.split()
# Out:
# ['Python', 'for', 'Beginners']

# %%
len(course.split())
# Out:
# 3
